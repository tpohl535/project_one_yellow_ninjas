# %%
# Dependencies and setup.
import os
import csv
import pandas as pd

# Import ethnicity data.
path_eth15 = os.path.join("Enrollment Report_Statewide_Campuses_Ethnicity_2014-2015.csv")
path_eth16 = os.path.join("Enrollment Report_Statewide_Campuses_Ethnicity_2015-2016.csv")
path_eth17 = os.path.join("Enrollment Report_Statewide_Campuses_Ethnicity_2016-2017.csv")
path_eth18 = os.path.join("Enrollment Report_Statewide_Campuses_Ethnicity_2017-2018.csv")
path_eth19 = os.path.join("Enrollment Report_Statewide_Campuses_Ethnicity_2018-2019.csv")

# Convert ethnicity data to pandas data frame.
df_eth15 = pd.read_csv(path_eth15)
df_eth16 = pd.read_csv(path_eth16)
df_eth17 = pd.read_csv(path_eth17)
df_eth18 = pd.read_csv(path_eth18)
df_eth19 = pd.read_csv(path_eth19)

# %%
# Display first dataframe to understand data structure.
df_eth15
# Out:
#             Year  Region     County Name   District Name  District Number  \
# 0      2014-2015       1  HIDALGO COUNTY       DONNA ISD           108902
# 1      2014-2015      10     HUNT COUNTY  GREENVILLE ISD           116905
# 2      2014-2015      10     HUNT COUNTY  GREENVILLE ISD           116905
# 3      2014-2015      10     HUNT COUNTY  GREENVILLE ISD           116905
# 4      2014-2015      10     HUNT COUNTY  GREENVILLE ISD           116905
# ...          ...     ...             ...             ...              ...
# 45889  2014-2015       4   HARRIS COUNTY       KLEIN ISD           101915
# 45890  2014-2015       4   HARRIS COUNTY       KLEIN ISD           101915
# 45891  2014-2015       4   HARRIS COUNTY       KLEIN ISD           101915
# 45892  2014-2015       4   HARRIS COUNTY       KLEIN ISD           101915
# 45893  2014-2015       4   HARRIS COUNTY       KLEIN ISD           101915
#
#             Campus Name  Campus Number                    Ethnicity Name  \
# ...

# %%
# Filter each dataframes to display only Travis County ethnicity data.
df_eth15_travis = df_eth15.loc[df_eth15["County Name"] == "TRAVIS COUNTY"]

# Drop Region and County columns after sorting.
df_eth15_travis = df_eth15_travis.drop(df_eth15_travis.columns[[1, 2]], axis=1)

# Create column for Grade Group for consistency. 
df_eth15_travis.insert(5, "Grade Group", "")
df_eth15_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 342  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 343  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 344  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 345  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 423  2014-2015    AUSTIN ISD           227901                  AKINS H S
#
#      Campus Number Grade Group             Ethnicity Name  \
# 342      227909005                                  Asian
# 343      227909005                               Hispanic
# 344      227909005                      Two or More Races
# 345      227909005                                  White
# 423      227901017              Black or African American
#
#      Enrollment by Ethnicity
# 342                 -9999999
# 343                        5
# 344                 -9999999
# 345                       31
# ...

# %%
# Filter each dataframes to display only Travis County ethnicity data.
df_eth16_travis = df_eth16.loc[df_eth16["County Name"] == "TRAVIS COUNTY"]

# Drop Region and County columns after sorting.
df_eth16_travis = df_eth16_travis.drop(df_eth16_travis.columns[[1, 2]], axis=1)

# Create column for Grade Group for consistency. 
df_eth16_travis.insert(5, "Grade Group", "")
df_eth16_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 333  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 334  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 335  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 417  2015-2016    AUSTIN ISD           227901                  AKINS H S
# 418  2015-2016    AUSTIN ISD           227901                  AKINS H S
#
#      Campus Number Grade Group                    Ethnicity Name  \
# 333      227909005                                         Asian
# 334      227909005                                      Hispanic
# 335      227909005                                         White
# 417      227901017                     Black or African American
# 418      227901017              American Indian or Alaska Native
#
#      Enrollment by Ethnicity
# 333                 -9999999
# 334                        5
# 335                       20
# ...

# %%
# Filter each dataframes to display only Travis County ethnicity data.
df_eth17_travis = df_eth17.loc[df_eth17["County Name"] == "TRAVIS COUNTY"]

# Drop Region and County columns after sorting.
df_eth17_clean_travis = df_eth17_travis.drop(df_eth17_travis.columns[[1, 2]], axis=1)
df_eth17_clean_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 332  2016-2017     EANES ISD           227909  ADULT TRANSITION SERVICES
# 333  2016-2017     EANES ISD           227909  ADULT TRANSITION SERVICES
# 334  2016-2017     EANES ISD           227909  ADULT TRANSITION SERVICES
# 335  2016-2017     EANES ISD           227909  ADULT TRANSITION SERVICES
# 336  2016-2017     EANES ISD           227909  ADULT TRANSITION SERVICES
#
#      Campus Number  Grade Group             Ethnicity Name  \
# 332      227909005  HIGH SCHOOL  Black or African American
# 333      227909005  HIGH SCHOOL                      Asian
# 334      227909005  HIGH SCHOOL                   Hispanic
# 335      227909005  HIGH SCHOOL          Two or More Races
# 336      227909005  HIGH SCHOOL                      White
#
#      Enrollment by Ethnicity
# 332                 -9999999
# 333                 -9999999
# 334                        5
# 335                 -9999999
# ...

# %%
# Filter each dataframes to display only Travis County ethnicity data.
df_eth18_travis = df_eth18.loc[df_eth18["County Name"] == "TRAVIS COUNTY"]

# Drop Region and County columns after sorting.
df_eth18_clean_travis = df_eth18_travis.drop(df_eth18_travis.columns[[1, 2]], axis=1)
df_eth18_clean_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 341  2017-2018     EANES ISD           227909  ADULT TRANSITION SERVICES
# 342  2017-2018     EANES ISD           227909  ADULT TRANSITION SERVICES
# 343  2017-2018     EANES ISD           227909  ADULT TRANSITION SERVICES
# 344  2017-2018     EANES ISD           227909  ADULT TRANSITION SERVICES
# 345  2017-2018     EANES ISD           227909  ADULT TRANSITION SERVICES
#
#      Campus Number  Grade Group             Ethnicity Name  \
# 341      227909005  HIGH SCHOOL  Black or African American
# 342      227909005  HIGH SCHOOL                      Asian
# 343      227909005  HIGH SCHOOL                   Hispanic
# 344      227909005  HIGH SCHOOL          Two or More Races
# 345      227909005  HIGH SCHOOL                      White
#
#      Enrollment by Ethnicity
# 341                 -9999999
# 342                 -9999999
# 343                 -9999999
# 344                 -9999999
# ...

# %%
# Creating dictionary of Campus Number and Grade Group.
grade_gr_dict = df_eth18_travis.set_index(["Campus Number"])["Grade Group"].to_dict()
grade_gr_dict
# Out:
# {227909005: 'HIGH SCHOOL',
#  227901017: 'HIGH SCHOOL',
#  227901101: 'ELEMENTARY',
#  227803103: 'ELEMENTARY',
#  227901012: 'ELEMENTARY / SECONDARY',
#  227901009: 'HIGH SCHOOL',
#  227901102: 'ELEMENTARY',
#  227806017: 'ELEMENTARY / SECONDARY',
#  227825001: 'ELEMENTARY / SECONDARY',
#  227821101: 'ELEMENTARY',
#  227901002: 'HIGH SCHOOL',
#  227901194: 'ELEMENTARY',
#  227806040: 'ELEMENTARY / SECONDARY',
#  227901250: 'ELEMENTARY / SECONDARY',
#  227901059: 'MIDDLE SCHOOL',
#  227901187: 'ELEMENTARY',
#  227901182: 'ELEMENTARY',
#  227901149: 'ELEMENTARY',
#  227909105: 'ELEMENTARY',
#  227901103: 'ELEMENTARY',
#  227910108: 'ELEMENTARY',
#  227901104: 'ELEMENTARY',
#  227901054: 'MIDDLE SCHOOL',
#  227913103: 'ELEMENTARY',
#  227901105: 'ELEMENTARY',
#  227907105: 'ELEMENTARY',
#  227901106: 'ELEMENTARY',
#  227901185: 'ELEMENTARY',
#  227907102: 'ELEMENTARY',
#  227901170: 'ELEMENTARY',
#  227901013: 'HIGH SCHOOL',
#  227901107: 'ELEMENTARY',
#  227909106: 'ELEMENTARY',
# ...

# %%
# Add Grade Group data to 2014-2015 ethnicity dataframe.
df_eth15_travis["Grade Group"] = df_eth15_travis["Campus Number"].map(grade_gr_dict)
df_eth15_clean_travis = df_eth15_travis
df_eth15_clean_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 342  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 343  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 344  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 345  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 423  2014-2015    AUSTIN ISD           227901                  AKINS H S
#
#      Campus Number  Grade Group             Ethnicity Name  \
# 342      227909005  HIGH SCHOOL                      Asian
# 343      227909005  HIGH SCHOOL                   Hispanic
# 344      227909005  HIGH SCHOOL          Two or More Races
# 345      227909005  HIGH SCHOOL                      White
# 423      227901017  HIGH SCHOOL  Black or African American
#
#      Enrollment by Ethnicity
# 342                 -9999999
# 343                        5
# 344                 -9999999
# 345                       31
# ...

# %%
# Add Grade Group data to 2015-2016 ethnicity dataframe.
df_eth16_travis["Grade Group"] = df_eth16_travis["Campus Number"].map(grade_gr_dict)
df_eth16_clean_travis = df_eth16_travis
df_eth16_clean_travis.head()
# Out:
#           Year District Name  District Number                Campus Name  \
# 333  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 334  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 335  2015-2016     EANES ISD           227909  ADULT TRANSITION SERVICES
# 417  2015-2016    AUSTIN ISD           227901                  AKINS H S
# 418  2015-2016    AUSTIN ISD           227901                  AKINS H S
#
#      Campus Number  Grade Group                    Ethnicity Name  \
# 333      227909005  HIGH SCHOOL                             Asian
# 334      227909005  HIGH SCHOOL                          Hispanic
# 335      227909005  HIGH SCHOOL                             White
# 417      227901017  HIGH SCHOOL         Black or African American
# 418      227901017  HIGH SCHOOL  American Indian or Alaska Native
#
#      Enrollment by Ethnicity
# 333                 -9999999
# 334                        5
# 335                       20
# ...

# %%
# Displaying 5th dataframe for 2018-2019 ethnicity data also reveals differences compared to other years in column order, column names and fonts.

# Filter each dataframes to display only Travis County ethnicity data.
df_eth19_travis = df_eth19.loc[df_eth19["COUNTY NAME"] == "TRAVIS COUNTY"]

# Drop Region and County columns after sorting.
df_eth19_travis = df_eth19_travis.drop(df_eth19_travis.columns[[1, 2]], axis=1)

df_eth19_travis.head()
# Out:
#             YEAR  DISTRICT    DISTRICT NAME     CAMPUS  \
# 42464  2018-2019    227803  WAYSIDE SCHOOLS  227803001
# 42465  2018-2019    227803  WAYSIDE SCHOOLS  227803001
# 42466  2018-2019    227803  WAYSIDE SCHOOLS  227803001
# 42467  2018-2019    227803  WAYSIDE SCHOOLS  227803001
# 42468  2018-2019    227803  WAYSIDE SCHOOLS  227803001
#
#                            CAMPUS NAME                      ETHNICITY  \
# 42464  WAYSIDE SCI-TECH MIDDLE AND H S  American Indian or Alaska Nat
# 42465  WAYSIDE SCI-TECH MIDDLE AND H S                          Asian
# 42466  WAYSIDE SCI-TECH MIDDLE AND H S      Black or African American
# 42467  WAYSIDE SCI-TECH MIDDLE AND H S                Hispanic/Latino
# 42468  WAYSIDE SCI-TECH MIDDLE AND H S              Two or more races
#
#              GRADE GROUP NAME  ENROLLMENT
# 42464  ELEMENTARY / SECONDARY           1
# 42465  ELEMENTARY / SECONDARY           6
# 42466  ELEMENTARY / SECONDARY          30
# ...

# %%
# Change 2018-2019 Travis County ethnicity data column name and font to match other years.
df_eth19_travis.columns = map(str.title, df_eth19_travis.columns)

df_eth19_travis.rename(columns = {"District":"District Number", "Campus":"Campus Number", "Grade Group Name":"Grade Group", "Ethnicity":"Ethnicity Name",
                          "Enrollment":"Enrollment by Ethnicity" }, inplace = True) 

df_eth19_travis.head()
# Out:
#             Year  District Number    District Name  Campus Number  \
# 42464  2018-2019           227803  WAYSIDE SCHOOLS      227803001
# 42465  2018-2019           227803  WAYSIDE SCHOOLS      227803001
# 42466  2018-2019           227803  WAYSIDE SCHOOLS      227803001
# 42467  2018-2019           227803  WAYSIDE SCHOOLS      227803001
# 42468  2018-2019           227803  WAYSIDE SCHOOLS      227803001
#
#                            Campus Name                 Ethnicity Name  \
# 42464  WAYSIDE SCI-TECH MIDDLE AND H S  American Indian or Alaska Nat
# 42465  WAYSIDE SCI-TECH MIDDLE AND H S                          Asian
# 42466  WAYSIDE SCI-TECH MIDDLE AND H S      Black or African American
# 42467  WAYSIDE SCI-TECH MIDDLE AND H S                Hispanic/Latino
# 42468  WAYSIDE SCI-TECH MIDDLE AND H S              Two or more races
#
#                   Grade Group  Enrollment by Ethnicity
# 42464  ELEMENTARY / SECONDARY                        1
# ...

# %%
# Swap 2018-2019 Travis County ethnicity data column order (for District Number and District Name) for consistency.

cols1 = list(df_eth19_travis.columns)
a, b = cols1.index("District Number"), cols1.index("District Name")
cols1[a], cols1[b] = cols1[b], cols1[a]
df_eth19_travis = df_eth19_travis[cols1]

cols2 = list(df_eth19_travis.columns)
c, d = cols2.index("Campus Number"), cols2.index("Campus Name")
cols2[c], cols2[d] = cols2[d], cols2[c]
df_eth19_travis = df_eth19_travis[cols2]

cols3 = list(df_eth19_travis.columns)
e, f = cols3.index("Ethnicity Name"), cols3.index("Grade Group")
cols3[e], cols3[f] = cols3[f], cols3[e]
df_eth19_clean_travis = df_eth19_travis[cols3]
df_eth19_clean_travis.head()
# Out:
#             Year    District Name  District Number  \
# 42464  2018-2019  WAYSIDE SCHOOLS           227803
# 42465  2018-2019  WAYSIDE SCHOOLS           227803
# 42466  2018-2019  WAYSIDE SCHOOLS           227803
# 42467  2018-2019  WAYSIDE SCHOOLS           227803
# 42468  2018-2019  WAYSIDE SCHOOLS           227803
#
#                            Campus Name  Campus Number             Grade Group  \
# 42464  WAYSIDE SCI-TECH MIDDLE AND H S      227803001  ELEMENTARY / SECONDARY
# 42465  WAYSIDE SCI-TECH MIDDLE AND H S      227803001  ELEMENTARY / SECONDARY
# 42466  WAYSIDE SCI-TECH MIDDLE AND H S      227803001  ELEMENTARY / SECONDARY
# 42467  WAYSIDE SCI-TECH MIDDLE AND H S      227803001  ELEMENTARY / SECONDARY
# 42468  WAYSIDE SCI-TECH MIDDLE AND H S      227803001  ELEMENTARY / SECONDARY
#
#                       Ethnicity Name  Enrollment by Ethnicity
# 42464  American Indian or Alaska Nat                        1
# 42465                          Asian                        6
# ...

# %%
# Concatenate all 5 years' dataframes for Travis County ethnicity data, and reset index to avoid duplicate indices.

df_eth5yrs_travis = pd.concat([df_eth15_clean_travis, df_eth16_clean_travis, df_eth17_clean_travis, df_eth18_clean_travis, df_eth19_clean_travis])
df_eth5yrs_clean_travis = df_eth5yrs_travis.reset_index(drop=True)
df_eth5yrs_clean_travis.head()
# Out:
#         Year District Name  District Number                Campus Name  \
# 0  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 1  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 2  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 3  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 4  2014-2015    AUSTIN ISD           227901                  AKINS H S
#
#    Campus Number  Grade Group             Ethnicity Name  \
# 0      227909005  HIGH SCHOOL                      Asian
# 1      227909005  HIGH SCHOOL                   Hispanic
# 2      227909005  HIGH SCHOOL          Two or More Races
# 3      227909005  HIGH SCHOOL                      White
# 4      227901017  HIGH SCHOOL  Black or African American
#
#    Enrollment by Ethnicity
# 0                 -9999999
# 1                        5
# 2                 -9999999
# 3                       31
# 4                      193

# %%
# Rename columns

df_eth5yrs_clean_travis.rename(columns = {"District Name":"District_Name", "District Number":"District_Number",  "Campus Name":"Campus_Name", "Campus Number":"Campus_Number", "Grade Group":"Grade_Group", "Ethnicity Name":"Ethnicity",
                          "Enrollment by Ethnicity":"Enrollment"}, inplace = True) 

df_eth5yrs_clean_travis.head()
# Out:
#         Year District_Name  District_Number                Campus_Name  \
# 0  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 1  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 2  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 3  2014-2015     EANES ISD           227909  ADULT TRANSITION SERVICES
# 4  2014-2015    AUSTIN ISD           227901                  AKINS H S
#
#    Campus_Number  Grade_Group                  Ethnicity  Enrollment
# 0      227909005  HIGH SCHOOL                      Asian    -9999999
# 1      227909005  HIGH SCHOOL                   Hispanic           5
# 2      227909005  HIGH SCHOOL          Two or More Races    -9999999
# 3      227909005  HIGH SCHOOL                      White          31
# 4      227901017  HIGH SCHOOL  Black or African American         193

# %%
# Checking ethnicity types for duplicates.
df_eth5yrs_clean_travis["Ethnicity"].unique()
# Out:
# array(['Asian', 'Hispanic', 'Two or More Races', 'White',
#        'Black or African American', 'American Indian or Alaska Native',
#        'Native Hawaiian/Other or Pacific Islander',
#        'American Indian or Alaska Nat', 'Hispanic/Latino',
#        'Two or more races', 'Native Hawaiian/Other Pacific'], dtype=object)

# %%
# Renaming ethnicities for consistency and to avoid duplicates.

df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('Hispanic'),'Ethnicity'] = "Hispanic/Latino"
df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('Two or more races'), 'Ethnicity'] = "Multiracial"
df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('Two or More Races'), 'Ethnicity'] = "Multiracial"
df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('American Indian or Alaska Nat'),'Ethnicity'] = "American Indian or Alaska Native"
df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('Native Hawaiian/Other or Pacific Islander'),'Ethnicity'] = "Native Hawaiian/Other Pacific Islander"
df_eth5yrs_clean_travis.loc[df_eth5yrs_clean_travis.Ethnicity.str.contains('Native Hawaiian/Other Pacific'),'Ethnicity'] = "Native Hawaiian/Other Pacific Islander"

# %%
# Ethnicity types - final check.
df_eth5yrs_clean_travis["Ethnicity"].unique()
# Out:
# array(['Asian', 'Hispanic/Latino', 'Multiracial', 'White',
#        'Black or African American', 'American Indian or Alaska Native',
#        'Native Hawaiian/Other Pacific Islander'], dtype=object)

# %%
# Renaming Year with End-of-School-Year.

df_eth5yrs_clean_travis['Year'] = df_eth5yrs_clean_travis['Year'].replace('2014-2015', '2015')
df_eth5yrs_clean_travis['Year'] = df_eth5yrs_clean_travis['Year'].replace('2015-2016', '2016')
df_eth5yrs_clean_travis['Year'] = df_eth5yrs_clean_travis['Year'].replace('2016-2017', '2017')
df_eth5yrs_clean_travis['Year'] = df_eth5yrs_clean_travis['Year'].replace('2017-2018', '2018')
df_eth5yrs_clean_travis['Year'] = df_eth5yrs_clean_travis['Year'].replace('2018-2019', '2019')
df_eth5yrs_clean_travis
# Out:
#       Year    District_Name  District_Number                Campus_Name  \
# 0     2015        EANES ISD           227909  ADULT TRANSITION SERVICES
# 1     2015        EANES ISD           227909  ADULT TRANSITION SERVICES
# 2     2015        EANES ISD           227909  ADULT TRANSITION SERVICES
# 3     2015        EANES ISD           227909  ADULT TRANSITION SERVICES
# 4     2015       AUSTIN ISD           227901                  AKINS H S
# ...    ...              ...              ...                        ...
# 7525  2019  LAKE TRAVIS ISD           227913      WEST CYPRESS HILLS EL
# 7526  2019  LAKE TRAVIS ISD           227913      WEST CYPRESS HILLS EL
# 7527  2019  LAKE TRAVIS ISD           227913      WEST CYPRESS HILLS EL
# 7528  2019  LAKE TRAVIS ISD           227913      WEST CYPRESS HILLS EL
# 7529  2019  LAKE TRAVIS ISD           227913      WEST CYPRESS HILLS EL
#
#       Campus_Number  Grade_Group                               Ethnicity  \
# ...

# %%
# Output to a CSV file the final concatenated dataframe for 5 years of Travis County ethnicity data.

df_eth5yrs_clean_travis.to_csv("Output_ethnicity_5yrs_clean_Travis.csv", index=False)
