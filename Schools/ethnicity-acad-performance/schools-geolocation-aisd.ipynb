# %%
# GEOLOCATION DATA / SCHOOL CAMPUS APIs for AISD

# Dependencies and setup.
import os
import csv
import pandas as pd
import numpy as np

# Import ethnicity data.
path_ethnicity = os.path.join("Output_ethnicity_5yrs_clean_Travis.csv")
path_geoloc = os.path.join("schools_geolocation_aisd_edited.csv")

# Convert ethnicity data to pandas data frame.
df_ethnicity = pd.read_csv(path_ethnicity)
df_geoloc = pd.read_csv(path_geoloc)

# %%
df_geoloc
# Out:
#                      Campus_Name        Lat        Lng  \
# 0                      AKINS H S  30.148702 -97.801704
# 1                     ALLISON EL  30.235847 -97.691485
# 2    ALTERNATIVE LEARNING CENTER  30.255675 -97.697152
# 3                   ANDERSON H S  30.375657 -97.752790
# 4                     ANDREWS EL  30.317534 -97.679668
# ..                           ...        ...        ...
# 116                      WINN EL  30.313854 -97.665306
# 117                WOOLDRIDGE EL  30.364893 -97.709931
# 118                    WOOTEN EL  30.352942 -97.719157
# 119                    ZAVALA EL  30.258243 -97.719881
# 120                    ZILKER EL  30.252544 -97.774567
#
#                                                Address  Zipcode
# 0                10701 S 1st St, Austin, TX 78748, USA    78748
# 1                 515 Vargas Rd, Austin, TX 78741, USA    78741
# 2              4900 Gonzales St, Austin, TX 78702, USA    78702
# 3                  8403 Mesa Dr, Austin, TX 78759, USA    78759
# 4             6801 Northeast Dr, Austin, TX 78723, USA    78723
# ..                                                 ...      ...
# 116         3500 Susquehanna Ln, Austin, TX 78723, USA    78723
# 117       1412 Norseman Terrace, Austin, TX 78758, USA    78758
# 118                1406 Dale Dr, Austin, TX 78757, USA    78757
# 119  310 Robert T Martinez Jr St, Austin, TX 78702,...    78702
# 120          1900 Bluebonnet Ln, Austin, TX 78704, USA    78704
#
# [121 rows x 5 columns]

# %%
df_geoloc["Campus_Number"] = ""
df_geoloc = df_geoloc[["Campus_Name", "Campus_Number", "Lat", "Lng", "Address", "Zipcode"]]
df_geoloc.set_index("Campus_Name")
# Out:
#                             Campus_Number        Lat        Lng  \
# Campus_Name
# AKINS H S                                  30.148702 -97.801704
# ALLISON EL                                 30.235847 -97.691485
# ALTERNATIVE LEARNING CENTER                30.255675 -97.697152
# ANDERSON H S                               30.375657 -97.752790
# ANDREWS EL                                 30.317534 -97.679668
# ...                                   ...        ...        ...
# WINN EL                                    30.313854 -97.665306
# WOOLDRIDGE EL                              30.364893 -97.709931
# WOOTEN EL                                  30.352942 -97.719157
# ZAVALA EL                                  30.258243 -97.719881
# ZILKER EL                                  30.252544 -97.774567
#
#                                                                        Address  \
# Campus_Name
# AKINS H S                                10701 S 1st St, Austin, TX 78748, USA
# ALLISON EL                                515 Vargas Rd, Austin, TX 78741, USA
# ALTERNATIVE LEARNING CENTER            4900 Gonzales St, Austin, TX 78702, USA
# ANDERSON H S                               8403 Mesa Dr, Austin, TX 78759, USA
# ANDREWS EL                            6801 Northeast Dr, Austin, TX 78723, USA
# ...                                                                        ...
# WINN EL                             3500 Susquehanna Ln, Austin, TX 78723, USA
# WOOLDRIDGE EL                     1412 Norseman Terrace, Austin, TX 78758, USA
# WOOTEN EL                                  1406 Dale Dr, Austin, TX 78757, USA
# ZAVALA EL                    310 Robert T Martinez Jr St, Austin, TX 78702,...
# ZILKER EL                            1900 Bluebonnet Ln, Austin, TX 78704, USA
#
#                              Zipcode
# Campus_Name
# AKINS H S                      78748
# ALLISON EL                     78741
# ALTERNATIVE LEARNING CENTER    78702
# ANDERSON H S                   78759
# ANDREWS EL                     78723
# ...                              ...
# WINN EL                        78723
# WOOLDRIDGE EL                  78758
# WOOTEN EL                      78757
# ZAVALA EL                      78702
# ZILKER EL                      78704
#
# [121 rows x 5 columns]

# %%
# Create dictionary of Campus Name and Campus Number from ethnicity dataset.
campus_dict = df_ethnicity.set_index(["Campus_Name"])["Campus_Number"].to_dict()
campus_dict
# Out:
# {'ADULT TRANSITION SERVICES': 227909005,
#  'AKINS H S': 227901017,
#  'ALLISON EL': 227901101,
#  'ALTERNATIVE LEARNING CENTER': 227901012,
#  'ANDERSON H S': 227901009,
#  'ANDREWS EL': 227901102,
#  'ANNUNCIATION MATERNITY HOME': 227806017,
#  'AUSTIN ACHIEVE PUBLIC SCHOOLS': 227825001,
#  'AUSTIN DISCOVERY SCH': 227821101,
#  'AUSTIN H S': 227901002,
#  'AUSTIN ST HOSPITAL': 227901250,
#  'BAILEY M S': 227901059,
#  'BALDWIN EL': 227901187,
#  'BARANOFF EL': 227901182,
#  'BARRINGTON EL': 227901149,
#  'BARTON CREEK EL': 227909105,
#  'BARTON HILLS EL': 227901103,
#  'BATY EL': 227910108,
#  'BECKER EL': 227901104,
#  'BEDICHEK M S': 227901054,
#  'BEE CAVE EL': 227913103,
#  'BLACKSHEAR EL': 227901105,
#  'BLAKE MANOR EL': 227907105,
#  'BLANTON EL': 227901106,
#  'BLAZIER EL': 227901185,
#  'BLUEBONNET TRAIL EL': 227907102,
#  'BOONE EL': 227901170,
#  'BOWIE H S': 227901013,
#  'BRENTWOOD EL': 227901107,
#  'BRIDGE POINT EL': 227909106,
#  'BROOKE EL': 227901108,
#  'BROOKHOLLOW EL': 227904108,
#  'BROWN EL': 227901109,
#  'BRYKER WOODS EL': 227901110,
#  'BURNET M S': 227901046,
#  'CALDWELL EL': 227904114,
#  'CAMPBELL EL': 227901111,
#  'CASEY EL': 227901173,
#  'CASIS EL': 227901112,
#  'CEDAR CREEK EL': 227909102,
#  'CEDARS INTERNATIONAL ACADEMY': 227817101,
#  'CELE M S': 227904048,
#  'CHAPARRAL STAR ACADEMY': 227814001,
#  'CLAYTON EL': 227901184,
#  'COOK EL': 227901161,
#  'COPPERFIELD EL': 227904111,
#  'COVINGTON M S': 227901057,
#  'COWAN EL': 227901183,
#  'CREEDMOOR EL': 227910111,
#  'CROCKETT H S': 227901008,
#  'CUNNINGHAM EL': 227901113,
#  'DAEP- EL': 227901115,
#  'DAILEY M S': 227910043,
#  'DAVIS EL': 227901179,
#  'DAWSON EL': 227901114,
#  'DEARING EL': 227904120,
#  'DECKER EL': 227907104,
#  'DECKER M S': 227907042,
#  'DEL VALLE EL': 227910110,
#  'DEL VALLE H S': 227910001,
#  'DEL VALLE M S': 227910041,
#  'DEL VALLE OPPORTUNITY CTR': 227910002,
#  'DELCO PRI': 227904113,
#  "DELL CHILDREN'S MEDICAL CENTER": 227901249,
#  'DEPELCHIN-RICHMOND': 227806029,
#  'DESSAU EL': 227904105,
#  'DESSAU M S': 227904045,
#  'DOBIE M S': 227901055,
#  'DOBIE PK CENTER': 227901192,
#  'DOSS EL': 227901154,
#  'EANES EL': 227909101,
#  'EASTSIDE MEMORIAL AT THE JOHNSTON': 227901019,
#  'EDEN PARK ACADEMY': 227803101,
#  'FOREST TRAIL EL': 227909104,
#  'FULMORE M S': 227901043,
#  'GALINDO EL': 227901176,
#  'GARZA INDEPENDENCE H S': 227901015,
#  'GEORGE M KOZMETSKY SCHOOL': 227806015,
#  'GORZYCKI M S': 227901062,
#  'GOVALLE EL': 227901116,
#  'GRAHAM EL': 227901159,
#  'GUERRERO THOMPSON': 227901186,
#  'GULLETT EL': 227901117,
#  'HARMONY SCHOOL OF EXCELLENCE': 227816101,
#  'HARMONY SCHOOL OF INNOVATION - AUS': 227816005,
#  'HARMONY SCHOOL OF POLITICAL SCIENC': 227816004,
#  'HARMONY SCHOOL OF SCIENCE - AUSTIN': 227816003,
#  'HARMONY SCIENCE ACADEMY - AUSTIN': 227816001,
#  'HARMONY SCIENCE ACADEMY NORTH AUST': 227816002,
#  'HARRIS EL': 227901118,
#  'HART EL': 227901163,
#  'HELPING HAND': 227806032,
#  'HENDRICKSON H S': 227904004,
#  'HIGHLAND PARK EL': 227904116,
#  'HILL COUNTRY M S': 227909041,
#  'HILL EL': 227901155,
#  'HILLCREST EL': 227910107,
#  'HORNSBY-DUNLAP EL': 227910109,
#  'HOUSTON EL': 227901162,
#  'HUDSON BEND M S': 227913042,
#  'INTERNATIONAL H S': 227901029,
#  'JOHN B CONNALLY H S': 227904003,
#  'JOHN P OJEDA J H': 227910042,
#  'JORDAN EL': 227901178,
#  'JOSEPH GILBERT EL': 227910112,
#  'JOSLIN EL': 227901120,
#  'KEALING M S': 227901044,
#  'KELLY LANE M S': 227904046,
#  'KIKER EL': 227901180,
#  'KIPP AUSTIN ACADEMY OF ARTS & LETT': 227820042,
#  'KIPP AUSTIN BEACON PREP': 227820043,
#  'KIPP AUSTIN COLLEGE PREP': 227820041,
#  'KIPP AUSTIN COLLEGIATE': 227820001,
#  'KIPP AUSTIN COMUNIDAD': 227820101,
#  'KIPP AUSTIN CONNECTIONS EL': 227820102,
#  'KIPP AUSTIN LEADERSHIP EL': 227820104,
#  'KIPP AUSTIN OBRAS': 227820103,
#  'KIPP AUSTIN VISTA M S SCHOOLS': 227820044,
#  'KOCUREK EL': 227901172,
#  'LAGO VISTA EL': 227912101,
#  'LAGO VISTA H S': 227912001,
#  'LAGO VISTA M S': 227912041,
#  'LAKE POINTE EL': 227913104,
#  'LAKE TRAVIS EL': 227913101,
#  'LAKE TRAVIS H S': 227913001,
#  'LAKE TRAVIS M S': 227913041,
#  'LAKEWAY EL': 227913102,
#  'LAMAR M S': 227901045,
#  'LANGFORD EL': 227901168,
#  'LANIER H S': 227901004,
#  'LASA H S': 227901018,
#  'LAUREL RIDGE': 227806030,
#  'LBJ HIGH SCHOOL': 227901014,
#  'LEADERSHIP ACADEMY': 227901035,
#  'LEE EL': 227901121,
#  'LINDER EL': 227901160,
#  'MAGNOLIA MONTESSORI FOR ALL': 227826101,
#  'MANOR EL': 227907101,
#  'MANOR EXCEL ACADEMY': 227907002,
#  'MANOR H S': 227907001,
#  'MANOR M S': 227907041,
#  'MANOR NEW TECHNOLOGY HIGH': 227907004,
#  'MAPLEWOOD EL': 227901122,
#  'MARTIN M S': 227901051,
#  'MATHEWS EL': 227901123,
#  'MCBEE EL': 227901165,
#  'MCCALLUM H S': 227901005,
#  'MENCHACA EL': 227901147,
#  'MENDEZ M S': 227901058,
#  "METHODIST CHILDREN'S HOME": 227806025,
#  'METZ EL': 227901124,
#  'MILLS EL': 227901181,
#  'MURCHISON EL': 227904112,
#  'MURCHISON M S': 227901052,
#  'NORMAN EL': 227901150,
#  'NORTHWEST EL': 227904104,
#  'NOT APPLICABLE': 227901000,
#  'NYOS - MAGNOLIA MCCULLOUGH CAMPUS': 227804102,
#  'NYOS CHARTER SCHOOL': 227804101,
#  'O HENRY M S': 227901047,
#  'OAK HILL EL': 227901148,
#  'OAK MEADOWS EL': 227907107,
#  'OAK SPRINGS EL': 227901125,
#  'ODOM EL': 227901156,
#  'OLYMPIA HILLS': 227806031,
#  'ORTEGA EL': 227901126,
#  'OVERTON EL': 227901189,
#  'PADRON EL': 227901188,
#  'PALM EL': 227901171,
#  'PAREDES M S': 227901061,
#  'PARK CREST M S': 227904043,
#  'PARMER LANE EL': 227904102,
#  'PATHFINDER CAMP': 227806009,
#  'PATHWAYS 3H CAMPUS': 227806023,
#  'PATTON EL': 227901143,
#  'PEASE EL': 227901128,
#  'PECAN SPRINGS EL': 227901129,
#  'PEREZ EL': 227901190,
#  'PFLUGERVILLE EL': 227904101,
#  'PFLUGERVILLE H S': 227904001,
#  'PFLUGERVILLE M S': 227904041,
#  'PHOENIX ACADEMY': 227901032,
#  'PICKLE EL': 227901164,
#  'PILLOW EL': 227901151,
#  'PIONEER CROSSING EL': 227907108,
#  'PLEASANT HILL EL': 227901130,
#  'POPHAM EL': 227910101,
#  'PREMIER H S AT LANIER': 227901026,
#  'PREMIER H S AT TRAVIS': 227901025,
#  'PRESIDENTIAL MEADOWS EL': 227907106,
#  'READ PRE-K DEMONSTRATION SCH': 227901131,
#  'REAGAN H S': 227901006,
#  'REAL LEARNING ACADEMY': 227803102,
#  'REILLY EL': 227901132,
#  'RICHARDS SCH FOR YOUNG WOMEN LEADE': 227901028,
#  'RIDGETOP EL': 227901133,
#  'RIOJAS EL': 227904118,
#  'RIVER OAKS EL': 227904107,
#  'RODRIGUEZ EL': 227901174,
#  'ROSEDALE': 227901251,
#  'ROWE LANE EL': 227904115,
#  'RUTH BARRON EL': 227904119,
#  'SADLER MEANS YWLA': 227901065,
#  'SANCHEZ EL': 227901127,
#  'SCHOOL FOR YOUNG MEN': 227901064,
#  'SCI-TECH PREPARATORY': 227803001,
#  'SERENE HILLS EL': 227913105,
#  'SETTLEMENT HOME': 227806005,
#  'SIMS EL': 227901139,
#  'SMALL M S': 227901060,
#  'SMITH EL': 227910106,
#  'SPRINGHILL EL': 227904109,
#  'ST ELMO EL': 227901136,
#  'SUMMITT EL': 227901138,
#  'SUNSET VALLEY EL': 227901158,
#  'TEXAS EMPOWERMENT ACADEMY': 227805041,
#  'TEXAS EMPOWERMENT ACADEMY EL': 227805101,
#  'THE EAST AUSTIN COLLEGE PREP ACADE': 227824001,
#  'THE EAST AUSTIN COLLEGE PREP AT ML': 227824002,
#  'THE EXCEL CENTER (FOR ADULTS)': 227827001,
#  'TIMMERMAN EL': 227904103,
#  'TNC CAMPUS (TEXAS NEUROREHABILITAT': 227806024,
#  'TRAVIS CO J J A E P': 227910005,
#  'TRAVIS COUNTY DAY SCHOOL': 227901027,
#  'TRAVIS COUNTY J J A E P': 227901036,
#  'TRAVIS COUNTY JUVENILE DETENTION C': 227901030,
#  'TRAVIS H S': 227901007,
#  'TRAVIS HTS EL': 227901140,
#  'UNIVERSITY OF TEXAS EL CHARTER SCH': 227819101,
#  'UPHAUS EARLY CHILDHOOD CENTER': 227901177,
#  'UT - UNIVERSITY CHARTER SCHOOL AT': 227806034,
#  'VALLEY VIEW EL': 227909103,
#  'WALNUT CREEK EL': 227901141,
#  'WEBB M S': 227901053,
#  'WEBB PRI CENTER': 227901193,
#  'WEST CYPRESS HILLS EL': 227913106,
#  'WEST RIDGE M S': 227909042,
#  'WESTLAKE H S': 227909001,
#  'WESTVIEW M S': 227904042,
#  'WIDEN EL': 227901175,
#  'WIELAND EL': 227904117,
#  'WILLIAMS EL': 227901166,
#  'WINDERMERE EL': 227904106,
#  'WINDERMERE PRI': 227904110,
#  'WINN EL': 227901157,
#  'WOOLDRIDGE EL': 227901152,
#  'WOOTEN EL': 227901144,
#  'ZAVALA EL': 227901145,
#  'ZILKER EL': 227901146,
#  'ALTAMIRA ACADEMY': 227803103,
#  'AUSTIN ISD CHILD DEVELOPMENT CENTE': 227901194,
#  'AUSTIN OAKS': 227806040,
#  'GARCIA YMLA': 227901064,
#  'GRADUATION PREP ACADEMY LANIER': 227901026,
#  'GRADUATION PREP ACADEMY TRAVIS': 227901025,
#  'HOUSTON BEHAVIORAL HEALTHCARE': 227806042,
#  'LIFEHOUSE': 227806039,
#  'READ PRE-K CENTER': 227901131,
#  'ROCK SPRINGS': 227806036,
#  'SHADOWGLEN EL': 227907109,
#  'SHRINERS HOSPITALS FOR CHILDREN': 227806037,
#  'THE EXCEL CENTER': 227828001,
#  'TRAVIS COUNTY JJAEP': 227912002,
#  'UNIVERSITY H S': 227806043,
#  'UNLIMITED VISIONS AFTERCARE': 227806041,
#  'CATES ACADEMY': 227806047,
#  'CEDAR CREST': 227806045,
#  'CEDARS ACADEMY NEXT GENERATION H S': 227817001,
#  'EXCEL CENTER LOCKHART': 227828002,
#  'GEORGETOWN BEHAVIORAL HEALTH INSTI': 227806044,
#  'HARMONY SCHOOL OF POLITICAL SCI AN': 227816004,
#  'HARMONY SCIENCE ACADEMY-PFLUGERVIL': 227816002,
#  'KIPP AUSTIN BRAVE': 227820002,
#  'LAGO VISTA INT': 227912102,
#  'SETON HOME': 227806046,
#  'THE EAST AUSTIN COLLEGE PREP AT SO': 227824001,
#  'HARMONY SCHOOL OF EXCELLENCE - AUS': 227816101,
#  'HARMONY SCIENCE ACADEMY - CEDAR PA': 227816006,
#  'JOHN P OJEDA M S': 227910042,
#  'KOZMETSKY AT RATHGEBER VILLAGE': 227806049,
#  'LAGOS EL': 227907111,
#  'MANOR NEW TECHNOLOGY M S': 227907043,
#  'MOTT EL': 227904121,
#  'NEW PRE-K CENTER': 227907110,
#  'WEISS H S': 227904005,
#  'WAYSIDE SCI-TECH M S AND H S': 227803001,
#  'WAYSIDE EDEN PARK ACADEMY': 227803101,
#  'WAYSIDE REAL LEARNING ACADEMY': 227803102,
#  'WAYSIDE ALTAMIRA ACADEMY': 227803103,
#  'MUNDAY': 227806049,
#  'THE REFUGE': 227806051,
#  'SJRC TEXAS': 227806052,
#  'HARMONY SCHOOL OF ENDEAVOR AUSTIN': 227816004,
#  'KIPP HOUSTON H S': 227820013,
#  'KIPP GENERATIONS COLLEGIATE': 227820014,
#  'KIPP NORTHEAST COLLEGE PREPARATORY': 227820015,
#  'KIPP SUNNYSIDE H S': 227820016,
#  'KIPP CONNECT H S': 227820017,
#  'KIPP UNIVERSITY PREP H S': 227820020,
#  'KIPP OAK CLIFF ACADEMY': 227820030,
#  'KIPP ACADEMY M S': 227820050,
#  'KIPP 3D ACADEMY': 227820051,
#  'KIPP SHARPSTOWN COLEGE PREP': 227820052,
#  'KIPP POLARIS ACADEMY FOR BOYS': 227820053,
#  'KIPP INTREPID PREPARATORY': 227820054,
#  'KIPP VOYAGE ACADEMY FOR GIRLS': 227820055,
#  'KIPP CONNECT M S': 227820056,
#  'KIPP LIBERATION COLLEGE PREPARATOR': 227820057,
#  'KIPP SPIRIT COLLEGE PREP': 227820058,
#  'KIPP ACADEMY WEST M S': 227820059,
#  'KIPP PRIME COLLEGE PREPARATORY': 227820060,
#  'KIPP NEXUS M S': 227820061,
#  'KIPP TRUTH ACADEMY': 227820071,
#  'KIPP DESTINY M S': 227820072,
#  'KIPP PLEASANT GROVE M S': 227820073,
#  'KIPP ASPIRE ACADEMY': 227820081,
#  'KIPP CAMINO ACADEMY': 227820082,
#  'KIPP PODER ACADEMY': 227820083,
#  'KIPP SHINE PREP': 227820205,
#  'KIPP DREAM PREP': 227820206,
#  'KIPP SHARP PREP': 227820207,
#  'KIPP EXPLORE ACADEMY': 227820209,
#  'KIPP LEGACY PREPARATORY': 227820211,
#  'KIPP CONNECT HOUSTON PRI': 227820212,
#  'KIPP PEACE EL': 227820213,
#  'KIPP ZENITH ACADEMY': 227820214,
#  'KIPP UNITY PRI': 227820215,
#  'KIPP CLIMB ACADEMY': 227820216,
#  'KIPP NEXUS PRI': 227820217,
#  'KIPP DESTINY EL': 227820301,
#  'KIPP TRUTH EL': 227820302,
#  'KIPP PLEASANT GROVE PRI': 227820303,
#  'KIPP UN MUNDO DUAL LANGUAGE ACADEM': 227820401,
#  'KIPP ESPERANZA DUAL LANGUAGE ACADE': 227820402,
#  'PROMESA COLLEGE PREP BROWNSVILLE': 227824003,
#  'PROMESA COLLEGE PREP WEST CORPUS C': 227824004,
#  'AUSTIN ACHIEVE': 227825001,
#  'AUSTIN ACHIEVE NORTHEAST CAMPUS': 227825003,
#  'THE EXCEL CENTER FOR ADULTS - LOCK': 227827002,
#  'THE EXCEL CENTER FOR ADULTS - SOUT': 227827003,
#  'VALOR SOUTH AUSTIN': 227829001,
#  'MAINSPRING SCHOOLS': 227901197,
#  'NEWTON COLLINS EL': 227910113}

# %%
# Add Campus Number column to geolocation dataframe.
df_geoloc["Campus_Number"] = df_geoloc["Campus_Name"].map(campus_dict)
df_geoloc_campnum = df_geoloc
df_geoloc_campnum
# Out:
#                      Campus_Name  Campus_Number        Lat        Lng  \
# 0                      AKINS H S    227901017.0  30.148702 -97.801704
# 1                     ALLISON EL    227901101.0  30.235847 -97.691485
# 2    ALTERNATIVE LEARNING CENTER    227901012.0  30.255675 -97.697152
# 3                   ANDERSON H S    227901009.0  30.375657 -97.752790
# 4                     ANDREWS EL    227901102.0  30.317534 -97.679668
# ..                           ...            ...        ...        ...
# 116                      WINN EL    227901157.0  30.313854 -97.665306
# 117                WOOLDRIDGE EL    227901152.0  30.364893 -97.709931
# 118                    WOOTEN EL    227901144.0  30.352942 -97.719157
# 119                    ZAVALA EL    227901145.0  30.258243 -97.719881
# 120                    ZILKER EL    227901146.0  30.252544 -97.774567
#
#                                                Address  Zipcode
# 0                10701 S 1st St, Austin, TX 78748, USA    78748
# 1                 515 Vargas Rd, Austin, TX 78741, USA    78741
# 2              4900 Gonzales St, Austin, TX 78702, USA    78702
# 3                  8403 Mesa Dr, Austin, TX 78759, USA    78759
# 4             6801 Northeast Dr, Austin, TX 78723, USA    78723
# ..                                                 ...      ...
# 116         3500 Susquehanna Ln, Austin, TX 78723, USA    78723
# 117       1412 Norseman Terrace, Austin, TX 78758, USA    78758
# 118                1406 Dale Dr, Austin, TX 78757, USA    78757
# 119  310 Robert T Martinez Jr St, Austin, TX 78702,...    78702
# 120          1900 Bluebonnet Ln, Austin, TX 78704, USA    78704
#
# [121 rows x 6 columns]

# %%
# # Convert Campus Number from float to integer for consistency with other datasets.
df_geoloc_campnum['Campus_Number'] = np.array([int(x) if x % 1 == 0 else x for x in df_geoloc_campnum['Campus_Number']], dtype=object)

# %%
# Output to a CSV file the final dataframe for AISD school location APIs.

df_geoloc_campnum.to_csv("Output_schools_geolocation_aisd_edited.csv", index=False)
