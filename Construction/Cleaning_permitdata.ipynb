# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file = "constructiondataset.csv"

# %%
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df
# Out:
#        Index Permit Type   Permit Type Desc      Permit Num  \
# 0        1.0          PP    Plumbing Permit  2015-015610 PP
# 1        2.0          EP  Electrical Permit  2015-012488 EP
# 2        3.0          PP    Plumbing Permit  2015-040597 PP
# 3        4.0          PP    Plumbing Permit  2015-003336 PP
# 4        5.0          PP    Plumbing Permit  2015-003504 PP
# ...      ...         ...                ...             ...
# 49827    NaN          MP  Mechanical Permit  2019-004905 MP
# 49828    NaN          PP    Plumbing Permit  2019-004905 PP
# 49829    NaN          PP    Plumbing Permit  2019-004908 PP
# 49830    NaN          BP    Building Permit  2019-004914 BP
# 49831    NaN          BP    Building Permit  2019-004915 BP
#
#       Permit Class Mapped                           Permit Class  Work Class  \
# 0             Residential                            Residential  Irrigation
# 1              Commercial                            Sign Permit        Wall
# 2             Residential                            Residential  Irrigation
# 3              Commercial                             Commercial     Remodel
# 4             Residential                            Residential  Irrigation
# ...                   ...                                    ...         ...
# 49827         Residential            R- 101 Single Family Houses         New
# 49828         Residential            R- 101 Single Family Houses         New
# 49829         Residential                            Residential      Repair
# 49830          Commercial  C- 649 Demolition All Other Bldgs Com  Demolition
# 49831          Commercial  C- 649 Demolition All Other Bldgs Com  Demolition
#
#       Condominium               Project Name  \
# 0              No           3909 TRANQUIL LN
# 1              No        11814 JOLLYVILLE RD
# 2              No  3001 DEL CURTO RD UNIT 31
# 3              No   2900 SWISHER ST UNIT 206
# 4              No             3607 CHERRY LN
# ...           ...                        ...
# 49827          No         8221 CITY TOP BLVD
# 49828          No         8221 CITY TOP BLVD
# 49829          No             1714 W 34TH ST
# 49830          No            701 W BRAKER LN
# 49831          No            701 W BRAKER LN
#
#                                              Description  ...   Latitude  \
# 0                   installment of new irrigation system  ...  30.469342
# 1      New frontlit channel letter wall sign on backe...  ...  30.421922
# 2            Install new irrigation system to condo only  ...  30.240899
# 3      replacement of water heater to commercial bldg...  ...  30.288528
# 4      Connect new irrigation system to well label pe...  ...  30.297580
# ...                                                  ...  ...        ...
# 49827  New 2story single family residence with attach...  ...  30.303456
# 49828  New 2story single family residence with attach...  ...  30.303456
# 49829        Cap off water and wastewater lines for demo  ...  30.307359
# 49830  total demo of carwash bays and 1017 vacuum sta...  ...  30.381096
# 49831     total demo of carwash bays and vacuum stations  ...  30.381096
#
#        Longitude                     Location Total Existing Bldg SQFT  \
# 0     -97.682385  (30.46934237, -97.68238479)                      NaN
# 1     -97.755241  (30.42192193, -97.75524085)                      NaN
# 2     -97.778645  (30.24089878, -97.77864529)                      NaN
# 3     -97.726053  (30.28852847, -97.72605332)                      NaN
# 4     -97.780730  (30.29758031, -97.78072961)                      NaN
# ...          ...                          ...                      ...
# 49827 -97.625426  (30.30345579, -97.62542636)                      NaN
# 49828 -97.625426  (30.30345579, -97.62542636)                      NaN
# 49829 -97.753597  (30.30735909, -97.75359742)                   2938.0
# 49830 -97.685721  (30.38109624, -97.68572123)                      NaN
# 49831 -97.685721  (30.38109624, -97.68572123)                      NaN
#
#        Total Job Valuation  Number Of Floors Building Valuation  \
# 0                      NaN               0.0                NaN
# 1                   2000.0               1.0                NaN
# 2                      NaN               0.0                NaN
# 3                      NaN               1.0                NaN
# 4                      NaN               NaN                NaN
# ...                    ...               ...                ...
# 49827              50000.0               1.0                NaN
# 49828                  NaN               0.0                NaN
# 49829                  NaN               1.0                NaN
# 49830                  NaN               NaN                NaN
# 49831                  NaN               0.0                NaN
#
#       Electrical Valuation Remodel Unnamed: 33 Contractor Full Name
# 0                            500.0         NaN            Joe Bebee
# 1                              NaN         NaN                  NaN
# 2                            400.0         NaN                  NaN
# 3                            150.0         NaN                  NaN
# 4                            500.0         NaN                  NaN
# ...                            ...         ...                  ...
# 49827                          NaN         NaN       Kenneth Burger
# 49828                          NaN         NaN        Chet Schwartz
# 49829                          NaN         NaN         Robert Bowne
# 49830                          NaN         NaN     John Haldenstein
# 49831                       8000.0         NaN        Clayton Payne
#
# [49832 rows x 35 columns]

# %%
df.shape  # dimensionality of the DataFrame
# Out:
# (49832, 35)

# %%
# Drop rows missing data
df = (
    pd.read_csv("constructiondataset.csv")
    .drop(
        [
            "Index",
            "Total Existing Bldg SQFT",
            "Total Job Valuation",
            "Number Of Floors",
            "Building Valuation",
            "Electrical Valuation Remodel",
            "Unnamed: 33",
            "Contractor Full Name",
        ],
        axis=1,
    )
    .dropna(how="any")
)

# %%
df
# Out:
#       Permit Type   Permit Type Desc      Permit Num Permit Class Mapped  \
# 0              PP    Plumbing Permit  2015-015610 PP         Residential
# 1              EP  Electrical Permit  2015-012488 EP          Commercial
# 4              PP    Plumbing Permit  2015-003504 PP         Residential
# 5              MP  Mechanical Permit  2014-130514 MP         Residential
# 6              MP  Mechanical Permit  2015-000238 MP         Residential
# ...           ...                ...             ...                 ...
# 49827          MP  Mechanical Permit  2019-004905 MP         Residential
# 49828          PP    Plumbing Permit  2019-004905 PP         Residential
# 49829          PP    Plumbing Permit  2019-004908 PP         Residential
# 49830          BP    Building Permit  2019-004914 BP          Commercial
# 49831          BP    Building Permit  2019-004915 BP          Commercial
#
#                                 Permit Class  Work Class Condominium  \
# 0                                Residential  Irrigation          No
# 1                                Sign Permit        Wall          No
# 4                                Residential  Irrigation          No
# 5                R- 101 Single Family Houses         New          No
# 6                                Residential  Change Out          No
# ...                                      ...         ...         ...
# 49827            R- 101 Single Family Houses         New          No
# 49828            R- 101 Single Family Houses         New          No
# 49829                            Residential      Repair          No
# 49830  C- 649 Demolition All Other Bldgs Com  Demolition          No
# 49831  C- 649 Demolition All Other Bldgs Com  Demolition          No
#
#               Project Name                                        Description  \
# 0         3909 TRANQUIL LN               installment of new irrigation system
# 1      11814 JOLLYVILLE RD  New frontlit channel letter wall sign on backe...
# 4           3607 CHERRY LN  Connect new irrigation system to well label pe...
# 5          4007 BRIONES ST                                              Paste
# 6       2514 E STASSNEY LN      CHANGE OUT of HVAC to existing residence only
# ...                    ...                                                ...
# 49827   8221 CITY TOP BLVD  New 2story single family residence with attach...
# 49828   8221 CITY TOP BLVD  New 2story single family residence with attach...
# 49829       1714 W 34TH ST        Cap off water and wastewater lines for demo
# 49830      701 W BRAKER LN  total demo of carwash bays and 1017 vacuum sta...
# 49831      701 W BRAKER LN     total demo of carwash bays and vacuum stations
#
#                               Property Legal Description  ... Status Date  \
# 0           LOT 3 BLK J RACEWAY SINGLE FAMILY SUBD SEC 4  ...      5/1/15
# 1                                LOT 1 MAYFIELDBARR SUBD  ...      5/5/15
# 4      LOT 910 BLK 9 WALSH PLACE ON LAKE AUSTIN  10 F...  ...      2/2/16
# 5            LOT 18 BLK 96 MUELLER SEC VIIC SUBD AMENDED  ...     8/17/15
# 6                     LOT 19 BLK 8 PEPPERTREE PARK SEC 3  ...     2/26/15
# ...                                                  ...  ...         ...
# 49827              LOT 13 BLK D PARKER CREEK RANCH PHS 1  ...    11/22/19
# 49828              LOT 13 BLK D PARKER CREEK RANCH PHS 1  ...    11/21/19
# 49829         LOT 7  W30 FT OF LOT 8 BLK 3 BRYKERWOODS E  ...     3/15/19
# 49830  01042 AC OF LOT 3 MOORE D EDWARD SUBD NO 3 PRO...  ...     6/26/19
# 49831  01042 AC OF LOT 3 MOORE D EDWARD SUBD NO 3 PRO...  ...     6/26/19
#
#       Expires Date Completed Date   Original Address 1  Original City  \
# 0           5/1/15         5/1/15     3909 TRANQUIL LN         AUSTIN
# 1           5/5/15         5/5/15  11814 JOLLYVILLE RD         AUSTIN
# 4           2/2/16         2/2/16       3607 CHERRY LN         AUSTIN
# 5          8/17/15        8/17/15      4007 BRIONES ST         AUSTIN
# 6          2/26/15        2/26/15   2514 E STASSNEY LN         AUSTIN
# ...            ...            ...                  ...            ...
# 49827     11/22/19       11/22/19   8221 CITY TOP BLVD         AUSTIN
# 49828     11/21/19       11/21/19   8221 CITY TOP BLVD         AUSTIN
# 49829      3/15/19        3/15/19       1714 W 34TH ST         AUSTIN
# 49830      6/26/19        6/26/19      701 W BRAKER LN         AUSTIN
# 49831      6/26/19        6/26/19      701 W BRAKER LN         AUSTIN
#
#       Original State Original Zip   Latitude  Longitude  \
# 0                 TX        78728  30.469342 -97.682385
# 1                 TX        78759  30.421922 -97.755241
# 4                 TX        78703  30.297580 -97.780730
# 5                 TX        78723  30.292200 -97.696349
# 6                 TX        78744  30.194066 -97.748077
# ...              ...          ...        ...        ...
# 49827             TX        78724  30.303456 -97.625426
# 49828             TX        78724  30.303456 -97.625426
# 49829             TX        78703  30.307359 -97.753597
# 49830             TX        78753  30.381096 -97.685721
# 49831             TX        78753  30.381096 -97.685721
#
#                           Location
# 0      (30.46934237, -97.68238479)
# 1      (30.42192193, -97.75524085)
# 4      (30.29758031, -97.78072961)
# 5      (30.29220029, -97.69634937)
# 6      (30.19406633, -97.74807716)
# ...                            ...
# 49827  (30.30345579, -97.62542636)
# 49828  (30.30345579, -97.62542636)
# 49829  (30.30735909, -97.75359742)
# 49830  (30.38109624, -97.68572123)
# 49831  (30.38109624, -97.68572123)
#
# [34040 rows x 27 columns]

# %%
df.shape
# Out:
# (34040, 27)

# %%
#Renaming the columns to make it consistent
df1 = df.rename(columns=lambda s: s.lower().replace(" ", "_"))
df1
# Out:
#       permit_type   permit_type_desc      permit_num permit_class_mapped  \
# 0              PP    Plumbing Permit  2015-015610 PP         Residential
# 1              EP  Electrical Permit  2015-012488 EP          Commercial
# 4              PP    Plumbing Permit  2015-003504 PP         Residential
# 5              MP  Mechanical Permit  2014-130514 MP         Residential
# 6              MP  Mechanical Permit  2015-000238 MP         Residential
# ...           ...                ...             ...                 ...
# 49827          MP  Mechanical Permit  2019-004905 MP         Residential
# 49828          PP    Plumbing Permit  2019-004905 PP         Residential
# 49829          PP    Plumbing Permit  2019-004908 PP         Residential
# 49830          BP    Building Permit  2019-004914 BP          Commercial
# 49831          BP    Building Permit  2019-004915 BP          Commercial
#
#                                 permit_class  work_class condominium  \
# 0                                Residential  Irrigation          No
# 1                                Sign Permit        Wall          No
# 4                                Residential  Irrigation          No
# 5                R- 101 Single Family Houses         New          No
# 6                                Residential  Change Out          No
# ...                                      ...         ...         ...
# 49827            R- 101 Single Family Houses         New          No
# 49828            R- 101 Single Family Houses         New          No
# 49829                            Residential      Repair          No
# 49830  C- 649 Demolition All Other Bldgs Com  Demolition          No
# 49831  C- 649 Demolition All Other Bldgs Com  Demolition          No
#
#               project_name                                        description  \
# 0         3909 TRANQUIL LN               installment of new irrigation system
# 1      11814 JOLLYVILLE RD  New frontlit channel letter wall sign on backe...
# 4           3607 CHERRY LN  Connect new irrigation system to well label pe...
# 5          4007 BRIONES ST                                              Paste
# 6       2514 E STASSNEY LN      CHANGE OUT of HVAC to existing residence only
# ...                    ...                                                ...
# 49827   8221 CITY TOP BLVD  New 2story single family residence with attach...
# 49828   8221 CITY TOP BLVD  New 2story single family residence with attach...
# 49829       1714 W 34TH ST        Cap off water and wastewater lines for demo
# 49830      701 W BRAKER LN  total demo of carwash bays and 1017 vacuum sta...
# 49831      701 W BRAKER LN     total demo of carwash bays and vacuum stations
#
#                               property_legal_description  ... status_date  \
# 0           LOT 3 BLK J RACEWAY SINGLE FAMILY SUBD SEC 4  ...      5/1/15
# 1                                LOT 1 MAYFIELDBARR SUBD  ...      5/5/15
# 4      LOT 910 BLK 9 WALSH PLACE ON LAKE AUSTIN  10 F...  ...      2/2/16
# 5            LOT 18 BLK 96 MUELLER SEC VIIC SUBD AMENDED  ...     8/17/15
# 6                     LOT 19 BLK 8 PEPPERTREE PARK SEC 3  ...     2/26/15
# ...                                                  ...  ...         ...
# 49827              LOT 13 BLK D PARKER CREEK RANCH PHS 1  ...    11/22/19
# 49828              LOT 13 BLK D PARKER CREEK RANCH PHS 1  ...    11/21/19
# 49829         LOT 7  W30 FT OF LOT 8 BLK 3 BRYKERWOODS E  ...     3/15/19
# 49830  01042 AC OF LOT 3 MOORE D EDWARD SUBD NO 3 PRO...  ...     6/26/19
# 49831  01042 AC OF LOT 3 MOORE D EDWARD SUBD NO 3 PRO...  ...     6/26/19
#
#       expires_date completed_date   original_address_1  original_city  \
# 0           5/1/15         5/1/15     3909 TRANQUIL LN         AUSTIN
# 1           5/5/15         5/5/15  11814 JOLLYVILLE RD         AUSTIN
# 4           2/2/16         2/2/16       3607 CHERRY LN         AUSTIN
# 5          8/17/15        8/17/15      4007 BRIONES ST         AUSTIN
# 6          2/26/15        2/26/15   2514 E STASSNEY LN         AUSTIN
# ...            ...            ...                  ...            ...
# 49827     11/22/19       11/22/19   8221 CITY TOP BLVD         AUSTIN
# 49828     11/21/19       11/21/19   8221 CITY TOP BLVD         AUSTIN
# 49829      3/15/19        3/15/19       1714 W 34TH ST         AUSTIN
# 49830      6/26/19        6/26/19      701 W BRAKER LN         AUSTIN
# 49831      6/26/19        6/26/19      701 W BRAKER LN         AUSTIN
#
#       original_state original_zip   latitude  longitude  \
# 0                 TX        78728  30.469342 -97.682385
# 1                 TX        78759  30.421922 -97.755241
# 4                 TX        78703  30.297580 -97.780730
# 5                 TX        78723  30.292200 -97.696349
# 6                 TX        78744  30.194066 -97.748077
# ...              ...          ...        ...        ...
# 49827             TX        78724  30.303456 -97.625426
# 49828             TX        78724  30.303456 -97.625426
# 49829             TX        78703  30.307359 -97.753597
# 49830             TX        78753  30.381096 -97.685721
# 49831             TX        78753  30.381096 -97.685721
#
#                           location
# 0      (30.46934237, -97.68238479)
# 1      (30.42192193, -97.75524085)
# 4      (30.29758031, -97.78072961)
# 5      (30.29220029, -97.69634937)
# 6      (30.19406633, -97.74807716)
# ...                            ...
# 49827  (30.30345579, -97.62542636)
# 49828  (30.30345579, -97.62542636)
# 49829  (30.30735909, -97.75359742)
# 49830  (30.38109624, -97.68572123)
# 49831  (30.38109624, -97.68572123)
#
# [34040 rows x 27 columns]

# %%
# Clean up Permit Class category.
df1["permit_class"] = df1["permit_class"].replace(
    {
        "R- 101 Single Family Houses": "Single Family Houses",
        "R- 103 Two Family Bldgs": "Apartments",
        "C- 105 Five or More Family Bldgs": "Apartments",
        "C- 104 Three & Four Family Bldgs": "Apartments",
        "C- 101 Single Family Houses": "Apartments",
        "C- 103 Two Family Bldgs": "Apartments",
        "R- 434 Addition & Alterations": "Renovations/Remodel",
        "R- 435 Renovations/Remodel": "Renovations/Remodel",
        "R- 329 Res Structures Other Than Bldg": "Residential",
        "R- 102 Secondary Apartment": "Residential",
        "C- 329 Com Structures Other Than Bldg": "Commercial",
        "C- 328 Commercial Other Nonresident Bldg": "Commercial",
        "R- 438 Residential Garage/Carport Addn": "Residential",
        "C- 437 Addn, Alter, Convn-NonRes": "Renovations/Remodel",
        "C- 321 Pkg Garage Bldg & Open Deck": "Commercial",
        "R- 437 Residential Boat Dock": "Residential",
        "R- 645 Demolition One Family Homes": "Demolition",
        "R- 649 Demolition All Other Bldgs Res": "Demolition",
        "C- 649 Demolition All Other Bldgs Com": "Demolition",
        "C-1002 Commercial Remodel & Finish Out": "Renovations/Remodel",
        "R- 646 Demolition Two Family Bldgs": "Demolition",
        "R- 438 Residential Retaining Wall": "Residential",
        "C-2002 Commercial Boat Dock": "Commercial",
        "C- 648 Demolition 5 or More Family Bldgs": "Demolition",
        "R- 328 Resident Other Nonresident Bldg": "Residential",
        "C-1000 Commercial Remodel": "Renovations/Remodel",
        "More than one family bldg": "Apartments",
        "C-1001 Commercial Finish Out": "Commercial",
        "R- 330  Accessory Use to Primary": "Residential",
        "C- 327 Stores & Customer Services": "Stores and Customer Services",
        "C- 324 Office, Bank & Professional Bldgs": "Offices and Bank",
        "C- 213 Hotels, Motels, & Tourist Cabins": "Hotels, Motels & Tourist Cabins",
        "C- 319 Churches and Othr Religious Bldgs": "Churches and Othr Religious Bldgs",
        "C- 320 Industrial Bldgs": "Industrial Bldgs",
        "C - Medical Gas": "Medical Gas",
        "C- 325 Public Works & Utilities Bldgs": "Public Works & Utilities Bldgs",
        "C- 318 Amusement, Social & Rec Bldgs": "Amusement",
        "C- 323 Hospital & Institutional Bldgs": "Hospital & Institutional Bldgs",
        "R-2001 Relocation Residential": "Residential",
        "C- 214 Other Nonhousekeeping Shelter": "Commercial",
        "C- 322 Service Station & Repair Garage": "Service Stations & repair Garage",
    }
)
df1["permit_class"].value_counts()
# Out:
# Renovations/Remodel                         10847
# Single Family Houses                         8426
# Residential                                  8039
# Commercial                                   3593
# Apartments                                   1896
# Sign Permit                                   297
# Demolition                                    269
# Stores and Customer Services                  183
# Offices and Bank                              178
# C- 106 Mixed Use                               78
# Hotels, Motels & Tourist Cabins                58
# Churches and Othr Religious Bldgs              33
# C- 326 Schools & Other Educational Bldgs       30
# Industrial Bldgs                               30
# Medical Gas                                    30
# Public Works & Utilities Bldgs                 19
# Amusement                                      19
# Hospital & Institutional Bldgs                 10
# Service Stations & repair Garage                5
# Name: permit_class, dtype: int64

# %%
#checking the valid list of columns in data
df1.columns
# Out:
# Index(['permit_type', 'permit_type_desc', 'permit_num', 'permit_class_mapped',
#        'permit_class', 'work_class', 'condominium', 'project_name',
#        'description', 'property_legal_description', 'applied_date',
#        'issued_date', 'day_issued', 'calendar_year_issued',
#        'fiscal_year_issued', 'issuance_method', 'status_current',
#        'status_date', 'expires_date', 'completed_date', 'original_address_1',
#        'original_city', 'original_state', 'original_zip', 'latitude',
#        'longitude', 'location'],
#       dtype='object')

# %%
## Verify cities are unqiue
df1.original_city.unique()
# Out:
# array(['AUSTIN', 'EAST AUSTIN', 'BEE CAVE', 'LAKEWAY', 'ROLLINGWOOD',
#        'WEST LAKE HILLS', 'THE HILLS', 'PFLUGERVILLE', 'CEDAR PARK',
#        'ROUND ROCK', 'SUNSET VALLEY'], dtype=object)

# %%
df1["original_city"].value_counts()
# Out:
# AUSTIN             30620
# EAST AUSTIN         3225
# BEE CAVE              89
# LAKEWAY               47
# WEST LAKE HILLS       31
# ROLLINGWOOD           14
# PFLUGERVILLE           5
# SUNSET VALLEY          3
# THE HILLS              3
# ROUND ROCK             2
# CEDAR PARK             1
# Name: original_city, dtype: int64

# %%
# Filtering the dataframe on the basis of East Austin
df_data = ["EAST AUSTIN"]

# %%
clean_dataframe = df1[clean_df.original_city.isin(df_data)]

# %%
clean_dataframe
# Out:
#       permit_type permit_type_desc      permit_num permit_class_mapped  \
# 25             PP  Plumbing Permit  2015-050655 PP         Residential
# 168            PP  Plumbing Permit  2017-071443 PP         Residential
# 226            PP  Plumbing Permit  2018-055761 PP         Residential
# 229            PP  Plumbing Permit  2018-065649 PP         Residential
# 314            PP  Plumbing Permit  2019-186387 PP         Residential
# ...           ...              ...             ...                 ...
# 49544          PP  Plumbing Permit  2019-001226 PP          Commercial
# 49629          PP  Plumbing Permit  2019-001474 PP         Residential
# 49694          BP  Building Permit  2019-004606 BP         Residential
# 49696          PP  Plumbing Permit  2019-004606 PP         Residential
# 49754          PP  Plumbing Permit  2019-004715 PP         Residential
#
#               permit_class  work_class condominium             project_name  \
# 25             Residential  Irrigation          No           1103 BERGER ST
# 168            Residential  Irrigation          No       1613 CANTERBURY ST
# 226            Residential  Irrigation          No  2807 GOODWIN AVE UNIT B
# 229            Residential  Irrigation          No           2408 WILLOW ST
# 314            Residential  Irrigation          No    1302 E M FRANKLIN AVE
# ...                    ...         ...         ...                      ...
# 49544           Commercial     Remodel          No   1801 E 6TH ST UNIT 400
# 49629          Residential      Repair          No           1120 GUNTER ST
# 49694  Renovations/Remodel      Repair          No           1011 WILLOW ST
# 49696  Renovations/Remodel      Repair          No           1011 WILLOW ST
# 49754          Residential  Change Out          No            1607 ASTOR PL
#
#                                              description  \
# 25            Install new irrigation system to residence
# 168    New Irrigation installation with 6 zones to ne...
# 226                            Install irrigation system
# 229                                lawn sprinkler system
# 314                                New irrigation system
# ...                                                  ...
# 49544      first time tenant finish out for admin office
# 49629        Replace water line from meter to house only
# 49694           Tub to shower conversion to existing sfr
# 49696           Tub to shower conversion to existing sfr
# 49754            Replacement of an existing water heater
#
#                          property_legal_description  ... status_date  \
# 25                          LOT 20 BLK 8 BROOKSDALE  ...     5/15/15
# 168              LOT 7 BLK 5 OLT 47 DIV O RIVERSIDE  ...     6/14/17
# 226                        LOT 1 KNAPE WOODROW SUBD  ...      4/5/18
# 229                     015 AC OF OLT 40 DIVISION O  ...     7/18/18
# 314                     030 AC OF OLT 22 DIVISION B  ...    10/25/19
# ...                                             ...  ...         ...
# 49544                      LOT 1 1801 EAST 6TH SUBD  ...      5/6/19
# 49629  LOT 4 BLK 2 OLT 4849 DIV A PICKLE CLARA SUBD  ...      1/8/19
# 49694             LOT 6 BLK 3 OLT 3132 DIV O M K  T  ...     1/14/19
# 49696             LOT 6 BLK 3 OLT 3132 DIV O M K  T  ...     1/14/19
# 49754                LOT 51 OLT 19 DIV B GRANT PARK  ...     1/17/19
#
#       expires_date completed_date       original_address_1  original_city  \
# 25         5/15/15        5/15/15           1103 BERGER ST    EAST AUSTIN
# 168        6/14/17        6/14/17       1613 CANTERBURY ST    EAST AUSTIN
# 226         4/5/18         4/5/18  2807 GOODWIN AVE UNIT B    EAST AUSTIN
# 229        7/18/18        7/18/18           2408 WILLOW ST    EAST AUSTIN
# 314        4/21/20       10/24/19    1302 E M FRANKLIN AVE    EAST AUSTIN
# ...            ...            ...                      ...            ...
# 49544       5/6/19         5/6/19   1801 E 6TH ST UNIT 400    EAST AUSTIN
# 49629       1/8/19         1/8/19           1120 GUNTER ST    EAST AUSTIN
# 49694      1/14/19        1/14/19           1011 WILLOW ST    EAST AUSTIN
# 49696      1/14/19        1/14/19           1011 WILLOW ST    EAST AUSTIN
# 49754      1/17/19        1/17/19            1607 ASTOR PL    EAST AUSTIN
#
#       original_state original_zip   latitude  longitude  \
# 25                TX        78721  30.268842 -97.687691
# 168               TX        78702  30.256045 -97.728388
# 226               TX        78702  30.270592 -97.704066
# 229               TX        78702  30.253773 -97.717336
# 314               TX        78721  30.279015 -97.695021
# ...              ...          ...        ...        ...
# 49544             TX        78702  30.261854 -97.723536
# 49629             TX        78702  30.266390 -97.698458
# 49694             TX        78702  30.259157 -97.734270
# 49696             TX        78702  30.259157 -97.734270
# 49754             TX        78721  30.283196 -97.687944
#
#                           location
# 25     (30.26884173, -97.68769078)
# 168    (30.25604486, -97.72838783)
# 226    (30.27059247, -97.70406585)
# 229     (30.2537734, -97.71733553)
# 314    (30.27901519, -97.69502052)
# ...                            ...
# 49544  (30.26185385, -97.72353563)
# 49629  (30.26639024, -97.69845799)
# 49694  (30.25915668, -97.73426966)
# 49696  (30.25915668, -97.73426966)
# 49754  (30.28319563, -97.68794385)
#
# [3225 rows x 27 columns]

# %%
clean_dataframe.shape
# Out:
# (3225, 27)

# %%
# Finally create the new clean csv file data
clean_dataframe.to_csv("cleaned_again_permitdata.csv", index=False)
